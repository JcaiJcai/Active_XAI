# %%
# %cd /u/jcai1/code/usefulxai/code/my_method

import h5py
import numpy as np
import matplotlib.pyplot as plt
import torch
import json
from modules.mhim import MHIM
import cv2
import random
import seaborn as sns
import os
# Out:
# /scratch/bdem/jcai1/bdem_usefulxai/code/my_method

# %% [markdown]
# ## 第一步：读取特征和 patch 坐标（来自 .h5）

# %%
# 第一步：读取特征和 patch 坐标（来自 .h5）
import h5py
import torch

def load_features_and_coords(h5_path):
    with h5py.File(h5_path, 'r') as f:
        features = torch.from_numpy(f['features'][:])  # shape: [N, D]
        coords_ = f['coords'][:]  # shape: [N, 2], each is [x, y]
    print(f"Loaded {features.shape[0]} patches, feature dim: {features.shape[1]}, coords shape: {coords_.shape}")
    return features, coords_

features, coords = load_features_and_coords("/u/jcai1/code/usefulxai/data/camelyon16-clam/tumor_vs_normal_resnet_features/h5_files_labels/tumor_001.h5")
# features, coords = load_features_and_coords("/u/jcai1/code/usefulxai/data/camelyon16-clam/tumor_vs_normal_resnet_features/h5_files_labels/normal_001.h5")

x_min, x_max = coords[:, 0].min(), coords[:, 0].max()
y_min, y_max = coords[:, 1].min(), coords[:, 1].max()

print(f"X range: {x_min} → {x_max}")
print(f"Y range: {y_min} → {y_max}")
# Out:
# Loaded 36710 patches, feature dim: 1024, coords shape: (36710, 2)
# X range: 704 → 90880
# Y range: 10432 → 162304

# %%
print(coords[:10])
# Out:
# [[ 17856 153856]
#  [ 17856 154112]
#  [ 18112 153600]
#  [ 18112 153856]
#  [ 18112 154112]
#  [ 18112 154368]
#  [ 18368 153344]
#  [ 18368 153600]
#  [ 18368 153856]
#  [ 18368 154112]]

# %% [markdown]
# ## 第二步：读取已训练好模型的attention score

# %%
# Attention for TransMIL
pure = MHIM(da_act='relu',baseline='selfattn').eval()
pure.requires_grad_(False)

pure_cpt = torch.load('/u/jcai1/code/usefulxai/paper_results/trained_models/transmil_uncertainty_top40_0.01_0.01_2023_0512_1632/fold_0_model_best_auc.pt',map_location='cpu')

pure.load_state_dict(pure_cpt['model'], strict=False)
pure.eval()
with torch.no_grad():
    _, attns = pure.forward_test(features.unsqueeze(0),return_attn=True)
    attn = attns[-1].mean(dim=1).squeeze(0) # Take last layer
    print(attn.shape)
attn_scores = attn.cpu().numpy()
print(attn_scores)
# Out:
# torch.Size([36710])
# [2.4976615e-07 2.4976612e-07 2.4976612e-07 ... 8.2293074e-05 8.4924350e-06
#  2.1663578e-05]

# %%
# 得到每个坐标的attention
attn_norm = (attn_scores - attn_scores.min()) / (attn_scores.max() - attn_scores.min() + 1e-6)
coords_attn = {
    tuple(coords[i]): float(attn_norm[i]) for i in range(len(coords))
}
print(coords_attn)
for i, (x, y) in enumerate(coords[:5]):
    print(coords_attn[(x,y)])
# Out:
# {(17856, 153856): 4.055497697663668e-07, (17856, 154112): 4.055493718624348e-07, (18112, 153600): 4.055493718624348e-07, (18112, 153856): 4.055493718624348e-07, (18112, 154112): 4.055497697663668e-07, (18112, 154368): 4.055501392485894e-07, (18368, 153344): 4.055501392485894e-07, (18368, 153600): 4.055493718624348e-07, (18368, 153856): 4.055493718624348e-07, (18368, 154112): 4.055493718624348e-07, (18624, 151296): 4.055497697663668e-07, (18624, 151552): 4.055493718624348e-07, (18624, 151808): 4.055493718624348e-07, (18624, 153088): 4.055493718624348e-07, (18624, 153344): 4.055493718624348e-07, (18624, 153600): 4.055493718624348e-07, (18624, 153856): 4.055493718624348e-07, (18624, 154112): 4.055493718624348e-07, (18880, 151296): 4.055493718624348e-07, (18880, 151552): 4.055493718624348e-07, (18880, 151808): 4.055493718624348e-07, (18880, 152064): 4.055493718624348e-07, (18880, 152320): 4.055493718624348e-07, (18880, 152576): 4.055493718624348e-07, (18880, 152832): 4.055493718624348e-07, (18880, 153088): 4.055493718624348e-07, (18880, 153344): 4.055493718624348e-07, (18880, 153600): 4.055493718624348e-07, (18880, 153856): 4.055493718624348e-07, (18880, 154112): 4.055493718624348e-07, (19136, 151552): 4.055493718624348e-07, (19136, 151808): 4.055493718624348e-07, (19136, 152064): 4.055493718624348e-07, (19136, 152320): 4.055493718624348e-07, (19136, 152576): 4.055493718624348e-07, (19136, 152832): 4.055493718624348e-07, (19136, 153088): 4.055493718624348e-07, (19136, 153344): 4.055493718624348e-07, (19136, 153600): 4.055493718624348e-07, (19136, 153856): 4.055493718624348e-07, (19136, 154112): 4.055493718624348e-07, (19136, 154368): 4.055493718624348e-07, (19392, 152064): 4.055493718624348e-07, (19392, 152320): 4.055493718624348e-07, (19392, 152576): 4.055493718624348e-07, (19392, 152832): 4.055493718624348e-07, (19392, 153088): 4.055493718624348e-07, (19392, 153344): 4.055493718624348e-07, (19392, 153600): 4.055493718624348e-07, (19392, 153856): 4.055493718624348e-07, (19392, 154112): 4.055493718624348e-07, (19392, 154368): 4.055493718624348e-07, (19648, 152320): 4.055493718624348e-07, (19648, 152576): 4.055493718624348e-07, (19648, 152832): 4.055493718624348e-07, (19648, 153088): 4.055493718624348e-07, (19648, 153344): 4.055493718624348e-07, (19648, 153600): 4.055493718624348e-07, (19648, 153856): 4.055493718624348e-07, (19648, 154112): 4.055493718624348e-07, (19904, 152320): 4.055493718624348e-07, (19904, 152576): 4.055493718624348e-07, (19904, 152832): 4.055493718624348e-07, (19904, 153088): 4.055493718624348e-07, (19904, 153344): 4.055493718624348e-07, (19904, 153600): 4.055493718624348e-07, (19904, 153856): 4.055493718624348e-07, (19904, 154112): 4.055493718624348e-07, (20160, 152064): 4.055493718624348e-07, (20160, 152320): 4.055493718624348e-07, (20160, 152576): 4.055493718624348e-07, (20160, 152832): 4.055493718624348e-07, (20160, 153088): 4.055493718624348e-07, (20160, 153344): 4.055493718624348e-07, (20160, 153600): 4.055493718624348e-07, (20160, 153856): 4.055493718624348e-07, (20160, 154112): 4.055493718624348e-07, (20160, 154368): 4.055493718624348e-07, (20416, 152064): 4.055493718624348e-07, (20416, 152320): 4.055493718624348e-07, (20416, 152576): 4.055493718624348e-07, (20416, 152832): 4.055493718624348e-07, (20416, 153088): 4.055493718624348e-07, (20416, 153344): 4.055493718624348e-07, (20416, 153600): 4.055493718624348e-07, (20416, 153856): 4.055493718624348e-07, (20416, 154112): 4.055493718624348e-07, (20416, 154368): 4.055493718624348e-07, (20416, 154624): 4.055493718624348e-07, (20416, 154880): 4.055493718624348e-07, (20416, 155136): 4.055493718624348e-07, (20416, 155392): 4.055493718624348e-07, (20416, 155648): 4.055493718624348e-07, (20416, 155904): 4.055493718624348e-07, (20416, 156160): 4.055493718624348e-07, (20416, 156416): 4.055493718624348e-07, (20416, 156672): 4.055493718624348e-07, (20416, 156928): 4.055493718624348e-07, (20416, 157184): 4.055493718624348e-07, (20416, 157440): 4.055493718624348e-07, ...
# 4.055497697663668e-07
# 4.055493718624348e-07
# 4.055493718624348e-07
# 4.055493718624348e-07
# 4.055497697663668e-07

# %%
import numpy as np

# Step 2: 计算前 5% 的阈值
top_percent = 0.18  # 如果你想保留 top 0.01%，就设为 0.0001
threshold = np.quantile(attn_norm, 1 - top_percent)

# Step 3: 提取 top 5% 的索引和对应 attention
top_indices = np.where(attn_norm >= threshold)[0]
top_attn = attn_norm[top_indices].astype(np.float32)

# Step 4: 对 top 5% 的 attention 再归一化到 [0,1]
top_attn_norm = (top_attn - top_attn.min()) / (top_attn.max() - top_attn.min())
print(len(top_attn_norm))
print("Top-attn norm max:", top_attn_norm.max())

# Step 5: 构建仅包含 top 5% 的 coords_attn 映射
coords_attn_topk = {
    tuple(coords[i]): float(top_attn_norm[j])
    for j, i in enumerate(top_indices)
}

print(len(coords_attn_topk))
# Step 6: 打印前 5 个 top patch 的坐标和 attention 值
# for c, a in list(coords_attn_topk.items())[:10]:
#     print(f"{c}: {a:.4f}")

coords_set = set(map(tuple, coords))

coords_attn_filtered = {
    (x, y): attn for (x, y), attn in coords_attn_topk.items()
    if (x, y) in coords_set and left <= x < right and top <= y < bottom
}
print(len(coords_attn_filtered))
attn_vals = np.array(list(coords_attn_filtered.values()), dtype=np.float32)
attn_vals_norm = (attn_vals - attn_vals.min()) / (attn_vals.max() - attn_vals.min())
coords_attn_region = {
    key: float(attn_vals_norm[i])
    for i, key in enumerate(coords_attn_filtered.keys())
}

for c, a in list(coords_attn_region.items())[:5]:
    print(f"{c}: {a:.4f}")

temp = np.array(list(coords_attn_region.values()), dtype=np.float32)
temp = (temp - temp.min()) / (temp.max() - temp.min())

# Step 3: 构建新的归一化字典
coords_attn_region_norm = {
    key: float(temp[i])
    for i, key in enumerate(coords_attn_region.keys())
}

# ✅ 打印前几项检查
for c, a in list(coords_attn_region_norm.items())[:5]:
    print(f"{c}: {a:.4f}")

print(len(coords_attn_region))
print(coords_attn_region_norm)
print("Max attention value:", max(list(coords_attn_region_norm.values())))
print("Min attention value:", min(list(coords_attn_region_norm.values())))
# Out:
# 6617
# Top-attn norm max: 1.0
# 6617
# 550
# (60288, 129344): 0.0003
# (60288, 129856): 0.0005
# (60288, 130880): 0.0013
# (60288, 131136): 0.0026
# (60288, 131392): 0.0021
# (60288, 129344): 0.0003
# (60288, 129856): 0.0005
# (60288, 130880): 0.0013
# (60288, 131136): 0.0026
# (60288, 131392): 0.0021
# 550
# {(60288, 129344): 0.0003023305907845497, (60288, 129856): 0.0005498737446032465, (60288, 130880): 0.0012541119940578938, (60288, 131136): 0.0025746088940650225, (60288, 131392): 0.0021291112061589956, (60544, 127808): 0.0017935882788151503, (60544, 128320): 0.00013756842236034572, (60544, 130112): 7.678237307118252e-05, (60544, 130368): 0.0008418066427111626, (60544, 131904): 0.0014304716605693102, (60544, 132160): 0.01334693655371666, (60544, 132416): 0.005363968666642904, (60544, 132672): 0.00042350278818048537, (60800, 129856): 0.0018207820830866694, (60800, 130112): 0.00019235584477428347, (60800, 130368): 0.009737764485180378, (60800, 130624): 0.002420644275844097, (60800, 130880): 0.0008690004469826818, (60800, 131136): 2.7193756977794692e-05, (60800, 132160): 0.012411951087415218, (60800, 132416): 0.016323452815413475, (60800, 132672): 0.01006808876991272, (60800, 132928): 0.002464634133502841, (61056, 124736): 0.0014852590393275023, (61056, 130112): 0.0003851116052828729, (61056, 130880): 0.0002695381117518991, (61056, 131136): 0.0012269183062016964, (61056, 131392): 0.0008582029840908945, (61056, 131648): 0.006965200882405043, (61056, 131904): 0.0023326645605266094, (61056, 132160): 0.002602202584967017, (61056, 132416): 0.0006654472672380507, (61056, 132672): 0.01073913462460041, (61056, 132928): 0.011338996700942516, (61056, 133184): 0.0008362080552615225, (61312, 130624): 0.00042350278818048537, (61312, 131136): 0.0047753038816154, (61312, 131392): 0.003751938696950674, (61312, 131648): 0.007867394015192986, (61312, 131904): 0.0038619134575128555, (61312, 132160): 0.016455423086881638, (61312, 132928): 0.009116306900978088, (61312, 133184): 0.001875969348475337, (61312, 133440): 0.0015460449503734708, (61568, 123712): 0.0007590257446281612, (61568, 129600): 0.0053531713783741, (61568, 129856): 0.005006450694054365, (61568, 130112): 0.006651272997260094, (61568, 130368): 0.00012637098552659154, (61568, 132160): 4.958861609338783e-05, (61824, 121920): 0.0002583407040219754, (61824, 123712): 3.2792471756692976e-05, (61824, 130112): 0.0002255482249893248, (61824, 131904): 0.0002915330696851015, (61824, 132160): 0.0007590257446281612, (61824, 132416): 0.00010997474601026624, (61824, 132672): 0.0011221423046663404, (62080, 124224): 0.003905903548002243, (62080, 124736): 0.001270908280275762, (62080, 124992): 0.0017439995426684618, (62080, 125248): 0.005237597972154617, (62080, 129344): 0.0004071065632160753, (62080, 134720): 0.005122024565935135, (62336, 134464): 0.00028593436582013965, (62592, 133440): 0.0032900446094572544, (62592, 133696): 0.001270908280275762, (63104, 119872): 4.958861609338783e-05, (63360, 135744): 0.009573002345860004, (63616, 135744): 0.0002915330696851015, (64128, 133696): 0.0005006850697100163, (64384, 133696): 0.0006546497461386025, (64640, 122432): 0.0006490509840659797, (64896, 133184): 0.005022847093641758, (64896, 133696): 0.0012597107561305165, (64896, 134976): 0.010205657221376896, (65152, 134976): 0.0016284262528643012, (65408, 122944): 0.001193725853227079, (65664, 134976): 0.0010453599970787764, (66176, 122432): 0.0005226799985393882, (66176, 127808): 0.00042350278818048537, (66176, 128064): 0.0003851116052828729, (66176, 128320): 0.00017036088684108108, (66176, 134720): 0.0010725538013502955, (66176, 135232): 4.958861609338783e-05, (66176, 136000): 0.0006214573513716459, (66432, 122432): 1.0797522008942906e-05, (66432, 128064): 0.0016448224196210504, (66432, 128320): 0.00012637098552659154, (66432, 134976): 0.0014192741364240646, (66432, 135232): 0.004423384554684162, (66432, 135488): 0.003625568002462387, (66432, 136000): 0.002629796275869012, (66432, 136768): 0.00013196970394346863, (66688, 128320): 0.00139168044552207, (66688, 134976): 0.0006766446749679744, (66688, 135488): 0.004742511548101902, (66944, 122432): 7.15835703886114e-05, (67200, 120384): 0.00021994952112436295, (67456, 120896): 0.004197836387902498, (67456, 126016): 0.00026393940788693726, (67456, 126272): 8.238109148 ...
# Max attention value: 1.0
# Min attention value: 0.0

# %% [markdown]
# ## 第三步：根据mask文件得到绘制区间（level0）

# %%
from openslide import OpenSlide
import numpy as np

def get_tumor_region_from_mask(mask_path, mask_level=8):
    mask_slide = OpenSlide(mask_path)
    print("Level dimensions of mask:", mask_slide.level_dimensions)
    dims = mask_slide.level_dimensions[mask_level]
    mask_img = mask_slide.read_region((0, 0), mask_level, dims).convert("L")
    mask_arr = np.array(mask_img)
    
    mask_h, mask_w = mask_arr.shape
    x_range = (0, mask_w - 1)
    y_range = (0, mask_h - 1)
    print(f"Full X range of mask (level 8): {x_range}")
    print(f"Full Y range of mask (level 8): {y_range}")

    coords_ = np.argwhere(mask_arr == 2)
    if len(coords_) == 0:
        print("No tumor (label==2) found in entire mask!")
        return None
    
    y_min, x_min = coords_.min(axis=0)
    y_max, x_max = coords_.max(axis=0)

    print(f"Tumor region in mask level {mask_level}: x=[{x_min}, {x_max}], y=[{y_min}, {y_max}]")
    
    # 映射回 level 0 坐标
    downsample = mask_slide.level_downsamples[mask_level]
    region = int(x_min * downsample), int(y_min * downsample), int(x_max * downsample), int(y_max * downsample)
    print("Suggested tumor region (level 0):", region)
    
    coords_ = np.argwhere(mask_arr == 1)
    if len(coords_) == 0:
        print("No normal (label==1) found in entire mask!")
        return None
    
    y_min, x_min = coords_.min(axis=0)
    y_max, x_max = coords_.max(axis=0)

    print(f"Normal region in mask level {mask_level}: x=[{x_min}, {x_max}], y=[{y_min}, {y_max}]")
    
    # 映射回 level 0 坐标
    downsample = mask_slide.level_downsamples[mask_level]
    region = int(x_min * downsample), int(y_min * downsample), int(x_max * downsample), int(y_max * downsample)
    print("Suggested normal region (level 0):", region)
    
get_tumor_region_from_mask("/u/jcai1/code/usefulxai/data/camelyon16/masks/tumor_001_mask.tif")
# Out:
# Level dimensions of mask: ((97792, 221184), (48896, 110592), (24448, 55296), (12224, 27648), (6112, 13824), (3056, 6912), (1528, 3456), (764, 1728), (382, 864))
# Full X range of mask (level 8): (0, 381)
# Full Y range of mask (level 8): (0, 863)
# Tumor region in mask level 8: x=[274, 286], y=[479, 525]
# Suggested tumor region (level 0): (70144, 122624, 73216, 134400)
# Normal region in mask level 8: x=[3, 351], y=[57, 826]
# Suggested normal region (level 0): (768, 14592, 89856, 211456)

# %% [markdown]
# ## 第四步：在原图上绘制attention和groud-truth annotation轮廓

# %%
svs_path="/u/jcai1/code/usefulxai/data/camelyon16/images/tumor_001.tif"
slide = OpenSlide(svs_path)
print(slide.level_dimensions)
# Out:
# ((97792, 221184), (48896, 110592), (24448, 55296), (12224, 27648), (6112, 13824), (3056, 6912), (1528, 3456), (764, 1728), (382, 864), (191, 432))

# %%
# region = (70144, 122624, 73472, 134656)  # 在 level=0 下的 region
region = (60144, 112624, 74216, 144400)
# region = (60144, 112624, 74216, 144400)
left, top, right, bottom = region
w, h = right - left, bottom - top

# %%
base_img = np.array(slide.read_region((left, top), 0, (w, h)).convert("RGB"))
print(base_img.shape)
# Out:
# (31776, 14072, 3)

# %%
mask_path="/u/jcai1/code/usefulxai/data/camelyon16/masks/tumor_001_mask.tif"
mask_slide = OpenSlide(mask_path)

# %%
mask_img = mask_slide.read_region((left, top), 8, (w, h)).convert("L")
mask_arr = np.array(mask_img)
print(mask_arr.shape)
# Out:
# (31776, 14072)

# %%
coords_set = set(map(tuple, coords))
# for (x, y) in coords_attn:
#     if (x, y) in coords_set:
#         print(f"({x}, {y}) exists in coords!")
for (x, y) in coords_set:
    if (x, y) in coords_attn:
        print(f"({x}, {y}) exists in coords!")
# Out:
# (56448, 124992) exists in coords!
# (54080, 128128) exists in coords!
# (52032, 138624) exists in coords!
# (41152, 114880) exists in coords!
# (48576, 77504) exists in coords!
# (23744, 81856) exists in coords!
# (50496, 138880) exists in coords!
# (34752, 69568) exists in coords!
# (36032, 151552) exists in coords!
# (16320, 93376) exists in coords!
# (26560, 112064) exists in coords!
# (38592, 68800) exists in coords!
# (20160, 92608) exists in coords!
# (33216, 69824) exists in coords!
# (31168, 80320) exists in coords!
# (22976, 122816) exists in coords!
# (29632, 80576) exists in coords!
# (27584, 91072) exists in coords!
# (40640, 68288) exists in coords!
# (22208, 92096) exists in coords!
# (50880, 86976) exists in coords!
# (69760, 122176) exists in coords!
# (26048, 91328) exists in coords!
# (5568, 125632) exists in coords!
# (39104, 68544) exists in coords!
# (37056, 79040) exists in coords!
# (66176, 132928) exists in coords!
# (12224, 83392) exists in coords!
# (31680, 80064) exists in coords!
# (39872, 109248) exists in coords!
# (35520, 79296) exists in coords!
# (33472, 89792) exists in coords!
# (49984, 128128) exists in coords!
# (28096, 90816) exists in coords!
# (56768, 85696) exists in coords!
# (38336, 109504) exists in coords!
# (7616, 125120) exists in coords!
# (50368, 66240) exists in coords!
# (40384, 160512) exists in coords!
# (68224, 132416) exists in coords!
# (42944, 77760) exists in coords!
# (6080, 125376) exists in coords!
# (72064, 131648) exists in coords!
# (22464, 112064) exists in coords!
# (4032, 135872) exists in coords!
# (37568, 78784) exists in coords!
# (56640, 131712) exists in coords!
# (60288, 113216) exists in coords!
# (58240, 123712) exists in coords!
# (33984, 89536) exists in coords!
# (76416, 110272) exists in coords!
# (31936, 100032) exists in coords!
# (13504, 123840) exists in coords!
# (42176, 118720) exists in coords!
# (56704, 123968) exists in coords!
# (17344, 123072) exists in coords!
# (48832, 76480) exists in coords!
# (28352, 110784) exists in coords!
# (9920, 134592) exists in coords!
# (72576, 131392) exists in coords!
# (4544, 135616) exists in coords!
# (64128, 122432) exists in coords!
# (44224, 118208) exists in coords!
# (58752, 123456) exists in coords!
# (14208, 17984) exists in coords!
# (37824, 98752) exists in coords!
# (19392, 122560) exists in coords!
# (23232, 121792) exists in coords!
# (20416, 65728) exists in coords!
# (42688, 118464) exists in coords!
# (41664, 72128) exists in coords!
# (16256, 17472) exists in coords!
# (27840, 64192) exists in coords!
# (25280, 121280) exists in coords!
# (52544, 131712) exists in coords!
# (14720, 17728) exists in coords!
# (21696, 157696) exists in coords!
# (26304, 64448) exists in coords!
# (24256, 74944) exists in coords!
# (44992, 153600) exists in coords!
# (51008, 131968) exists in coords!
# (18880, 75968) exists in coords!
# (47552, 70848) exists in coords!
# (29120, 94656) exists in coords!
# (40128, 82368) exists in coords!
# (33728, 62912) exists in coords!
# (15296, 86720) exists in coords!
# (62848, 116800) exists in coords!
# (68480, 131392) exists in coords!
# (81024, 103360) exists in coords!
# (27584, 156416) exists in coords!
# (18112, 116928) exists in coords!
# (53056, 131456) exists in coords!
# (32192, 63168) exists in coords!
# (30144, 73664) exists in coords!
# (22208, 157440) exists in coords!
# (56896, 130688) exists in coords!
# (24768, 74688) exists in coords!
# (46016, 81088) exists in coords!
# (39616, 61632) exists in coords!
# (19136, 95936) exists in coords!
# (29376, 114624) exists in coords!
# (34240, 62656) exists in coords!
# (61312, 127040) exists in coords!
# (24000, 115648) exists in coords!
# (36032, 72384) exists in coords!
# (17600, 96192) exists in coords!
# (35008, 103360) exists in coords!
# (30656, 73408) exists in coords!
# (59776, 127296) exists in coords!
# (28608, 83904) exists in coords!
# (57280, 78784) exists in coords!
# (38848, 102592) exists in coords!
# (51904, 79808) exists in coords!
# (31424, 114112) exists in coords!
# (27072, 84160) exists in coords!
# (25024, 94656) exists in coords!
# (38080, 71872) exists in coords!
# (19648, 95680) exists in coords!
# (48320, 90560) exists in coords!
# (67200, 125760) exists in coords!
# (29888, 114368) exists in coords!
# (41920, 71104) exists in coords!
# (23488, 94912) exists in coords!
# (3008, 129216) exists in coords!
# (65664, 126016) exists in coords!
# (34496, 82624) exists in coords!
# (76928, 103360) exists in coords!
# (51840, 118080) exists in coords!
# (30912, 93376) exists in coords!
# (25536, 94400) exists in coords!
# (54208, 89280) exists in coords!
# (73088, 124480) exists in coords!
# (8896, 127936) exists in coords!
# (40384, 81344) exists in coords!
# (59264, 116544) exists in coords!
# (69504, 135232) exists in coords!
# (19904, 115648) exists in coords!
# (54080, 135296) exists in coords!
# (43200, 111552) exists in coords!
# (81280, 102336) exists in coords!
# (55680, 127296) exists in coords!
# (30656, 159744) exists in coords!
# (86784, 13760) exists in coords!
# (33216, 76992) exists in coords!
# (29120, 160000) exists in coords!
# (47040, 120768) exists in coords!
# (85248, 14016) exists in coords!
# (29632, 87744) exists in coords!
# (45504, 121024) exists in coords!
# (41920, 157440) exists in coords!
# (15808, 79808) exists in coords!
# (36544, 158464) exists in coords!
# (10432, 80832) exists in coords!
# (39104, 75712) exists in coords!
# (20672, 99520) exists in coords!
# (14272, 80064) exists in coords!
# (22720, 150528) exists in coords!
# (12224, 90560) exists in coords!
# (31680, 87232) exists in coords!
# (25280, 67776) exists in coords!
# (35520, 86464) exists in coords!
# (54400, 121664) exists in coords!
# (49984, 135296) exists in coords!
# (9664, 121792) exists in coords!
# (23744, 68032) exists in coords!
# (21696, 78528) exists in coords!
# (50368, 73408) exists in coords!
# (42432, 157184) exists in coords!
# (16320, 79552) exists in coords!
# (44992, 74432) exists in coords!
# (6080, 132544) exists in coords!
# (20160, 78784) exists in coords!
# (31168, 66496) exists in coords!
# (12736, 90304) exists in coords!
# (60288, 120384) exists in coords!
# (20928, 119488) exists in coords!
# (55872, 134016) exists in coords!
# (25024, 160000) exists in coords!
# (33984, 96704) exists in coords!
# (15552, 120512) exists in coords!
# (27584, 77248) exists in coords!
# (22208, 78272) exists in coords!
# (32448, 96960) exists in coords!
# (48832, 83648) exists in coords!
# (11968, 131264) exists in coords!
# (62336, 119872) exists in coords!
# (37056, 65216) exists in coords!
# (18624, 89024) exists in coords!
# (47296, 83904) exists in coords!
# (26816, 118208) exists in coords!
# (58752, 130624) exists in coords!
# (21440, 119232) exists in coords!
# (33472, 75968) exists in coords!
# (15040, 99776) exists in coords!
# (62592, 129856) exists in coords!
# (54720, 82368) exists in coords!
# (36288, 106176) exists in coords!
# (49344, 83392) exists in coords!
# (28864, 117696) exists in coords!
# (18304, 14144) exists in coords!
# (22464, 98240) exists in coords!
# (4032, 122048) exists in coords!
# (64640, 129344) exists in coords!
# (27328, 117952) exists in coords!
# (23744, 154368) exists in coords!
# (26304, 71616) exists in coords!
# (48576, 124352) exists in coords!
# (31936, 86208) exists in coords!
# (53184, 92608) exists in coords!
# (28352, 96960) exists in coords!
# (9920, 120768) exists in coords!
# (38592, 115648) exists in coords!
# (51648, 92864) exists in coords!
# (70528, 128064) exists in coords!
# (6336, 131520) exists in coords!
# (32192, 70336) exists in coords!
# (24768, 81856) exists in coords!
# (51520, 138880) exists in coords!
# (40640, 115136) exists in coords!
# (37056, 151552) exists in coords!
# (44480, 114368) exists in coords!
# (21184, 92608) exists in coords!
# (34240, 69824) exists in coords!
# (30656, 80576) exists in coords!
# (12672, 14400) exists in coords!
# (53376, 115008) exists in coords!
# (29120, 80832) exists in coords!
# (27072, 91328) exists in coords!
# (40128, 68544) exists in coords!
# (13248, 83392) exists in coords!
# (41920, 78272) exists in coords!
# (5056, 125888) exists in coords!
# (36544, 79296) exists in coords!
# (55424, 114496) exists in coords!
# (65664, 133184) exists in coords!
# (11712, 83648) exists in coords!
# (53888, 114752) exists in coords!
# (22720, 71360) exists in coords!
# (51392, 66240) exists in coords!
# (32960, 90048) exists in coords!
# (75392, 110784) exists in coords!
# (43968, 77760) exists in coords!
# (7104, 125376) exists in coords!
# (19136, 82112) exists in coords!
# (10944, 124608) exists in coords!
# (8896, 135104) exists in coords!
# (13760, 83136) exists in coords!
# (61312, 113216) exists in coords!
# (42432, 78016) exists in coords!
# (3520, 136128) exists in coords!
# (35008, 89536) exists in coords!
# (77440, 110272) exists in coords!
# (28608, 70080) exists in coords!
# (57728, 123968) exists in coords!
# (36800, 99264) exists in coords!
# (18368, 123072) exists in coords!
# (75904, 110528) exists in coords!
# (49856, 76480) exists in coords!
# (41664, 118976) exists in coords!
# (25024, 80832) exists in coords!
# (48320, 76736) exists in coords!
# (46272, 87232) exists in coords!
# (65152, 122432) exists in coords!
# (9408, 134848) exists in coords!
# (27840, 111040) exists in coords!
# (87296, 10688) exists in coords!
# (63616, 122688) exists in coords!
# (24256, 121792) exists in coords!
# (21440, 65728) exists in coords!
# (18880, 122816) exists in coords!
# (17856, 76480) exists in coords!
# (52160, 85952) exists in coords!
# (71040, 121152) exists in coords!
# (46784, 86976) exists in coords!
# (14272, 87232) exists in coords!
# (69504, 121408) exists in coords!
# (15744, 17728) exists in coords!
# (30144, 120512) exists in coords!
# (27328, 64448) exists in coords!
# (46016, 153600) exists in coords!
# (62080, 132928) exists in coords!
# (52032, 131968) exists in coords!
# (21184, 157952) exists in coords!
# (65920, 132160) exists in coords!
# (23744, 75200) exists in coords!
# (50496, 132224) exists in coords!
# (39616, 108480) exists in coords!
# (58048, 84672) exists in coords!
# (16320, 86720) exists in coords!
# (71552, 120896) exists in coords!
# (38592, 62144) exists in coords!
# (28608, 156416) exists in coords!
# (33216, 63168) exists in coords!
# (67968, 131648) exists in coords!
# (27072, 156672) exists in coords!
# (29632, 73920) exists in coords!
# (40640, 61632) exists in coords!
# (50880, 80320) exists in coords!
# (26048, 84672) exists in coords!
# (39104, 61888) exists in coords!
# (37056, 72384) exists in coords!
# (18624, 96192) exists in coords!
# (47296, 91072) exists in coords!
# (31680, 73408) exists in coords!
# (35520, 72640) exists in coords!
# (17088, 96448) exists in coords!
# (33472, 83136) exists in coords!
# (28096, 84160) exists in coords!
# (38336, 102848) exists in coords!
# (50816, 118592) exists in coords!
# (49344, 90560) exists in coords!
# (24512, 94912) exists in coords!
# (72064, 124992) exists in coords!
# (4032, 129216) exists in coords!
# (37568, 72128) exists in coords!
# (47808, 90816) exists in coords!
# (41408, 71360) exists in coords!
# (62272, 139648) exists in coords!
# (10688, 86976) exists in coords!
# (39360, 81856) exists in coords!
# (58240, 117056) exists in coords!
# (2496, 129472) exists in coords!
# (33984, 82880) exists in coords!
# (52864, 118080) exists in coords!
# (76416, 103616) exists in coords!
# (31936, 93376) exists in coords!
# (42176, 112064) exists in coords!
# (56704, 117312) exists in coords!
# (46272, 152576) exists in coords!
# (17344, 116416) exists in coords!
# (74112, 124480) exists in coords!
# (55232, 89280) exists in coords!
# (30400, 93632) exists in coords!
# (9920, 127936) exists in coords!
# (53696, 89536) exists in coords!
# (72576, 124736) exists in coords!
# (4544, 128960) exists in coords!
# (70528, 135232) exists in coords!
# (16576, 85696) exists in coords!
# (8384, 128192) exists in coords!
# (44224, 111552) exists in coords!
# (39872, 81600) exists in coords!
# (58752, 116800) exists in coords!
# (82304, 102336) exists in coords!
# (68992, 135488) exists in coords!
# (62592, 116032) exists in coords!
# (84224, 14528) exists in coords!
# (23232, 115136) exists in coords!
# (42688, 111808) exists in coords!
# (55168, 127552) exists in coords!
# (10432, 127680) exists in coords!
# (32704, 103104) exists in coords!
# (35520, 158976) exists in coords!
# (9408, 81344) exists in coords!
# (86272, 14016) exists in coords!
# (14720, 11072) exists in coords!
# (46528, 121024) exists in coords!
# (84736, 14272) exists in coords!
# (61056, 126272) exists in coords!
# (29120, 88000) exists in coords!
# (37568, 158464) exists in coords!
# (44992, 121280) exists in coords!
# (41408, 157696) exists in coords!
# (15296, 80064) exists in coords!
# (49600, 89536) exists in coords!
# (68480, 124736) exists in coords!
# (31168, 113344) exists in coords!
# (30144, 67008) exists in coords!
# (22208, 150784) exists in coords!
# (11712, 90816) exists in coords!
# (24768, 68032) exists in coords!
# (53888, 121920) exists in coords!
# (49472, 135552) exists in coords!
# (21184, 78784) exists in coords!
# (74368, 123456) exists in coords!
# (13760, 90304) exists in coords!
# (36032, 65728) exists in coords!
# (17600, 89536) exists in coords!
# (54720, 154880) exists in coords!
# (30656, 66752) exists in coords!
# (59776, 120640) exists in coords!
# (28608, 77248) exists in coords!
# (20416, 119744) exists in coords!
# (55360, 134272) exists in coords!
# (14016, 100288) exists in coords!
# (27072, 77504) exists in coords!
# (25024, 88000) exists in coords!
# (38080, 65216) exists in coords!
# (19648, 89024) exists in coords!
# (48320, 83904) exists in coords!
# (23488, 88256) exists in coords!
# (36544, 65472) exists in coords!
# (34496, 75968) exists in coords!
# (87296, 17856) exists in coords!
# (63616, 129856) exists in coords!
# (26304, 118464) exists in coords!
# (37312, 106176) exists in coords!
# (32960, 76224) exists in coords!
# (30912, 86720) exists in coords!
# (25536, 87744) exists in coords!
# (54208, 82624) exists in coords!
# (29376, 86976) exists in coords!
# (8896, 121280) exists in coords!
# (40384, 74688) exists in coords!
# (21952, 98496) exists in coords!
# (50624, 93376) exists in coords!
# (69504, 128576) exists in coords!
# (32192, 117184) exists in coords!
# (1472, 132800) exists in coords!
# (54080, 128640) exists in coords!
# (55680, 120640) exists in coords!
# (31424, 86464) exists in coords!
# (50304, 121664) exists in coords!
# (39616, 115648) exists in coords!
# (54144, 120896) exists in coords!
# (14784, 120000) exists in coords!
# (71552, 128064) exists in coords!
# (27840, 97216) exists in coords!
# (75392, 127296) exists in coords!
# (7360, 131520) exists in coords!
# (70016, 128320) exists in coords!
# (11648, 14912) exists in coords!
# (16832, 119488) exists in coords!
# (45504, 114368) exists in coords!
# (40128, 115392) exists in coords!
# (36544, 151808) exists in coords!
# (39104, 69056) exists in coords!
# (20672, 92864) exists in coords!
# (13696, 14400) exists in coords!
# (35520, 79808) exists in coords!
# (49984, 128640) exists in coords!
# (12160, 14656) exists in coords!
# (87552, 16832) exists in coords!
# (21696, 71872) exists in coords!
# (48448, 128896) exists in coords!
# (40384, 161024) exists in coords!
# (26560, 91584) exists in coords!
# (6080, 125888) exists in coords!
# (37568, 79296) exists in coords!
# (31168, 59840) exists in coords!
# (12736, 83648) exists in coords!
# (41408, 78528) exists in coords!
# (60288, 113728) exists in coords!
# (25024, 153344) exists in coords!
# (33984, 90048) exists in coords!
# (27584, 70592) exists in coords!
# (56704, 124480) exists in coords!
# (54336, 127616) exists in coords!
# (22208, 71616) exists in coords!
# (32448, 90304) exists in coords!
# (74880, 111040) exists in coords!
# (40896, 160768) exists in coords!
# (26048, 70848) exists in coords!
# (43456, 78016) exists in coords!
# (4544, 136128) exists in coords!
# (18624, 82368) exists in coords!
# (47296, 77248) exists in coords!
# (16576, 92864) exists in coords!
# (26816, 111552) exists in coords!
# (8384, 135360) exists in coords!
# (58752, 123968) exists in coords!
# (33472, 69312) exists in coords!
# (15040, 93120) exists in coords!
# (62592, 123200) exists in coords!
# (23232, 122304) exists in coords!
# (28096, 70336) exists in coords!
# (42688, 118976) exists in coords!
# (57216, 124224) exists in coords!
# (46784, 159488) exists in coords!
# (36288, 99520) exists in coords!
# (52800, 137856) exists in coords!
# (49344, 76736) exists in coords!
# (28864, 111040) exists in coords!
# (10432, 134848) exists in coords!
# (24512, 81088) exists in coords!
# (22464, 91584) exists in coords!
# (64640, 122688) exists in coords!
# (27328, 111296) exists in coords!
# (25280, 121792) exists in coords!
# (20928, 91840) exists in coords!
# (39360, 68032) exists in coords!
# (63104, 122944) exists in coords!
# (31936, 79552) exists in coords!
# (61056, 133440) exists in coords!
# (23744, 122048) exists in coords!
# (53184, 85952) exists in coords!
# (28352, 90304) exists in coords!
# (38592, 108992) exists in coords!
# (51648, 86208) exists in coords!
# (70528, 121408) exists in coords!
# (68480, 131904) exists in coords!
# (31168, 120512) exists in coords!
# (6336, 124864) exists in coords!
# (32192, 63680) exists in coords!
# (37824, 78272) exists in coords!
# (22208, 157952) exists in coords!
# (66944, 132160) exists in coords!
# (29632, 120768) exists in coords!
# (26048, 157184) exists in coords!
# (61568, 133184) exists in coords!
# (51520, 132224) exists in coords!
# (53120, 124224) exists in coords!
# (34240, 63168) exists in coords!
# (31680, 120256) exists in coords!
# (28096, 156672) exists in coords!
# (72832, 130880) exists in coords!
# (30656, 73920) exists in coords!
# (26560, 156928) exists in coords!
# (29120, 74176) exists in coords!
# (27072, 84672) exists in coords!
# (42944, 117952) exists in coords!
# (40128, 61888) exists in coords!
# (23488, 95424) exists in coords!
# (36544, 72640) exists in coords!
# (18112, 96448) exists in coords!
# (32960, 83392) exists in coords!
# (51840, 118592) exists in coords!
# (14976, 17216) exists in coords!
# (25536, 94912) exists in coords!
# (19136, 75456) exists in coords!
# (29376, 94144) exists in coords!
# (13760, 76480) exists in coords!
# (24000, 95168) exists in coords!
# (3520, 129472) exists in coords!
# (17600, 75712) exists in coords!
# (35008, 82880) exists in coords!
# (10176, 87232) exists in coords!
# (38848, 82112) exists in coords!
# (57728, 117312) exists in coords!
# (81280, 102848) exists in coords!
# (1984, 129728) exists in coords!
# (14016, 86464) exists in coords!
# (75904, 103872) exists in coords!
# (31424, 93632) exists in coords!
# (41664, 112320) exists in coords!
# (25024, 74176) exists in coords!
# (35264, 92864) exists in coords!
# (48320, 70080) exists in coords!
# (29888, 93888) exists in coords!
# (46272, 80576) exists in coords!
# (9408, 128192) exists in coords!
# (40896, 81600) exists in coords!
# (70016, 135488) exists in coords!
# (34496, 62144) exists in coords!
# (44736, 80832) exists in coords!
# (85248, 14528) exists in coords!
# (24256, 115136) exists in coords!
# (81792, 102592) exists in coords!
# (30912, 72896) exists in coords!
# (60032, 126784) exists in coords!
# (52160, 79296) exists in coords!
# (33728, 103104) exists in coords!
# (46784, 80320) exists in coords!
# (50624, 79552) exists in coords!
# (15744, 11072) exists in coords!
# (19904, 95168) exists in coords!
# (30144, 113856) exists in coords!
# (62080, 126272) exists in coords!
# (24768, 114880) exists in coords!
# (65920, 125504) exists in coords!
# (23744, 68544) exists in coords!
# (46016, 121280) exists in coords!
# (20160, 79296) exists in coords!
# (25792, 93888) exists in coords!
# (67968, 124992) exists in coords!
# (71808, 124224) exists in coords!
# (29632, 67264) exists in coords!
# (11200, 91072) exists in coords!
# (77696, 102592) exists in coords!
# (64384, 135744) exists in coords!
# (54336, 134784) exists in coords!
# (22208, 78784) exists in coords!
# (26048, 78016) exists in coords!
# (41920, 111296) exists in coords!
# (20672, 79040) exists in coords!
# (18624, 89536) exists in coords!
# (31680, 66752) exists in coords!
# (30912, 159232) exists in coords!
# (35520, 65984) exists in coords!
# (56384, 134272) exists in coords!
# (17088, 89792) exists in coords!
# (25536, 160256) exists in coords!
# (54208, 155136) exists in coords!
# (70272, 134464) exists in coords!
# (15040, 100288) exists in coords!
# (28096, 77504) exists in coords!
# (29376, 159488) exists in coords!
# (54848, 134528) exists in coords!
# (26560, 77760) exists in coords!
# (24512, 88256) exists in coords!
# (37568, 65472) exists in coords!
# (47808, 84160) exists in coords!
# (27328, 118464) exists in coords!
# (22976, 88512) exists in coords!
# (10688, 80320) exists in coords!
# (39360, 75200) exists in coords!
# (31424, 158976) exists in coords!
# (20928, 99008) exists in coords!
# (33984, 76224) exists in coords!
# (63104, 130112) exists in coords!
# (31936, 86720) exists in coords!
# (9152, 80576) exists in coords!
# (30400, 86976) exists in coords!
# (9920, 121280) exists in coords!
# (53696, 82880) exists in coords!
# (4544, 122304) exists in coords!
# (33216, 117184) exists in coords!
# (51648, 93376) exists in coords!
# (16576, 79040) exists in coords!
# (8384, 121536) exists in coords!
# (6336, 132032) exists in coords!
# (39872, 74944) exists in coords!
# (21440, 98752) exists in coords!
# (68992, 128832) exists in coords!
# (960, 133056) exists in coords!
# (4800, 132288) exists in coords!
# (55168, 120896) exists in coords!
# (15808, 120000) exists in coords!
# (44480, 114880) exists in coords!
# (10432, 121024) exists in coords!
# (39104, 115904) exists in coords!
# (22464, 77760) exists in coords!
# (12224, 130752) exists in coords!
# (74880, 127552) exists in coords!
# (6848, 131776) exists in coords!
# (42176, 84416) exists in coords!
# (61056, 119616) exists in coords!
# (21696, 118720) exists in coords!
# (11136, 15168) exists in coords!
# (16320, 119744) exists in coords!
# (44992, 114624) exists in coords!
# (49600, 82880) exists in coords!
# (11712, 84160) exists in coords!
# (66944, 118336) exists in coords!
# (13184, 14656) exists in coords!
# (27584, 117440) exists in coords!
# (17024, 13888) exists in coords!
# (49472, 128896) exists in coords!
# (63360, 129088) exists in coords!
# (47936, 129152) exists in coords!
# (47296, 124096) exists in coords!
# (13760, 83648) exists in coords!
# (17600, 82880) exists in coords!
# (59776, 113984) exists in coords!
# (28608, 70592) exists in coords!
# (24512, 153600) exists in coords!
# (14016, 93632) exists in coords!
# (27072, 70848) exists in coords!
# (49344, 123584) exists in coords!
# (53824, 127872) exists in coords!
# (51776, 138368) exists in coords!
# (19648, 82368) exists in coords!
# (48320, 77248) exists in coords!
# (23488, 81600) exists in coords!
# (18112, 82624) exists in coords!
# (34496, 69312) exists in coords!
# (16064, 93120) exists in coords!
# (26304, 111808) exists in coords!
# (7872, 135616) exists in coords!
# (32960, 69568) exists in coords!
# (14528, 93376) exists in coords!
# (30912, 80064) exists in coords!
# (25536, 81088) exists in coords!
# (35776, 99776) exists in coords!
# (29376, 80320) exists in coords!
# (46784, 87488) exists in coords!
# (40384, 68032) exists in coords!
# (21952, 91840) exists in coords!
# (50624, 86720) exists in coords!
# (69504, 121920) exists in coords!
# (35008, 69056) exists in coords!
# (38848, 68288) exists in coords!
# (36800, 78784) exists in coords!
# (65920, 132672) exists in coords!
# (31424, 79808) exists in coords!
# (39616, 108992) exists in coords!
# (35264, 79040) exists in coords!
# (52672, 86208) exists in coords!
# (71552, 121408) exists in coords!
# (27840, 90560) exists in coords!
# (56512, 85440) exists in coords!
# (25792, 101056) exists in coords!
# (7360, 124864) exists in coords!
# (51136, 86464) exists in coords!
# (70016, 121664) exists in coords!
# (67968, 132160) exists in coords!
# (30656, 120768) exists in coords!
# (24256, 101312) exists in coords!
# (5824, 125120) exists in coords!
# (71808, 131392) exists in coords!
# (3776, 135616) exists in coords!
# (66432, 132416) exists in coords!
# (77696, 109760) exists in coords!
# (60032, 112960) exists in coords!
# (58560, 84928) exists in coords!
# (2240, 135872) exists in coords!
# (40128, 108736) exists in coords!
# (76160, 110016) exists in coords!
# (41920, 118464) exists in coords!
# (17088, 96960) exists in coords!
# (72320, 131136) exists in coords!
# (4288, 135360) exists in coords!
# (43968, 117952) exists in coords!
# (19136, 122304) exists in coords!
# (26560, 84928) exists in coords!
# (42432, 118208) exists in coords!
# (41408, 71872) exists in coords!
# (22976, 95680) exists in coords!
# (47040, 86464) exists in coords!
# (16000, 17216) exists in coords!
# (27584, 63936) exists in coords!
# (9152, 87744) exists in coords!
# (46272, 153088) exists in coords!
# (32448, 83648) exists in coords!
# (51328, 118848) exists in coords!
# (14464, 17472) exists in coords!
# (26048, 64192) exists in coords!
# (53696, 90048) exists in coords!
# (18624, 75712) exists in coords!
# (47296, 70592) exists in coords!
# (16576, 86208) exists in coords!
# (8384, 128704) exists in coords!
# (39872, 82112) exists in coords!
# (33472, 62656) exists in coords!
# (15040, 86464) exists in coords!
# (62592, 116544) exists in coords!
# (28096, 63680) exists in coords!
# (38336, 82368) exists in coords!
# (57216, 117568) exists in coords!
# (80768, 103104) exists in coords!
# (46784, 152832) exists in coords!
# (17856, 116672) exists in coords!
# (52800, 131200) exists in coords!
# (10432, 128192) exists in coords!
# (24512, 74432) exists in coords!
# (32704, 103616) exists in coords!
# (47808, 70336) exists in coords!
# (45760, 80832) exists in coords!
# (39360, 61376) exists in coords!
# (31936, 72896) exists in coords!
# (84736, 14784) exists in coords!
# (61056, 126784) exists in coords!
# (23744, 115392) exists in coords!
# (17344, 95936) exists in coords!
# (53184, 79296) exists in coords!
# (34752, 103104) exists in coords!
# (44992, 121792) exists in coords!
# (59520, 127040) exists in coords!
# (28352, 83648) exists in coords!
# (38592, 102336) exists in coords!
# (51648, 79552) exists in coords!
# (33216, 103360) exists in coords!
# (49600, 90048) exists in coords!
# (31168, 113856) exists in coords!
# (26816, 83904) exists in coords!
# (37824, 71616) exists in coords!
# (19392, 95424) exists in coords!
# (48064, 90304) exists in coords!
# (66944, 125504) exists in coords!
# (29632, 114112) exists in coords!
# (90624, 13504) exists in coords!
# (23232, 94656) exists in coords!
# (61568, 126528) exists in coords!
# (51520, 125568) exists in coords!
# (53120, 117568) exists in coords!
# (55488, 88768) exists in coords!
# (74368, 123968) exists in coords!
# (51584, 117824) exists in coords!
# (50112, 89792) exists in coords!
# (31680, 113600) exists in coords!
# (53952, 89024) exists in coords!
# (72832, 124224) exists in coords!
# (67456, 125248) exists in coords!
# (65408, 135744) exists in coords!
# (69248, 134976) exists in coords!
# (29120, 67520) exists in coords!
# (77184, 102848) exists in coords!
# (63872, 136000) exists in coords!
# (53824, 135040) exists in coords!
# (42944, 111296) exists in coords!
# (56000, 88512) exists in coords!
# (10688, 127168) exists in coords!
# (36544, 65984) exists in coords!
# (18112, 89792) exists in coords!
# (71296, 134464) exists in coords!
# (30400, 159488) exists in coords!
# (32960, 76736) exists in coords!
# (14528, 100544) exists in coords!
# (53696, 155392) exists in coords!
# (84992, 13760) exists in coords!
# (29376, 87488) exists in coords!
# (24000, 88512) exists in coords!
# (3520, 122816) exists in coords!
# (35008, 76224) exists in coords!
# (10176, 80576) exists in coords!
# (38848, 75456) exists in coords!
# (20416, 99264) exists in coords!
# (14016, 79808) exists in coords!
# (31424, 86976) exists in coords!
# (25024, 67520) exists in coords!
# (35264, 86208) exists in coords!
# (54144, 121408) exists in coords!
# (29888, 87232) exists in coords!
# (9408, 121536) exists in coords!
# (23488, 67776) exists in coords!
# (40896, 74944) exists in coords!
# (51136, 93632) exists in coords!
# (70016, 128832) exists in coords!
# (16064, 79296) exists in coords!
# (44736, 74176) exists in coords!
# (7872, 121792) exists in coords!
# (5824, 132288) exists in coords!
# (56192, 120896) exists in coords!
# (30912, 66240) exists in coords!
# (12480, 90048) exists in coords!
# (60032, 120128) exists in coords!
# (49600, 155392) exists in coords!
# (40128, 115904) exists in coords!
# (54656, 121152) exists in coords!
# (33728, 96448) exists in coords!
# (15296, 120256) exists in coords!
# (50240, 134784) exists in coords!
# (50624, 72896) exists in coords!
# (32192, 96704) exists in coords!
# (19904, 88512) exists in coords!
# (11712, 131008) exists in coords!
# (62080, 119616) exists in coords!
# (22720, 118720) exists in coords!
# (36800, 64960) exists in coords!
# (87552, 17344) exists in coords!
# (46016, 114624) exists in coords!
# (60544, 119872) exists in coords!
# (58496, 130368) exists in coords!
# (21184, 118976) exists in coords!
# (34240, 96192) exists in coords!
# (25792, 87232) exists in coords!
# (36032, 105920) exists in coords!
# (49088, 83136) exists in coords!
# (47040, 93632) exists in coords!
# (28608, 117440) exists in coords!
# (18048, 13888) exists in coords!
# (11200, 84416) exists in coords!
# (64384, 129088) exists in coords!
# (27072, 117696) exists in coords!
# (54336, 128128) exists in coords!
# (23488, 154112) exists in coords!
# (59008, 130112) exists in coords!
# (48960, 129152) exists in coords!
# (38080, 105408) exists in coords!
# (26048, 71360) exists in coords!
# (48320, 124096) exists in coords!
# (52928, 92352) exists in coords!
# (31680, 60096) exists in coords!
# (17088, 83136) exists in coords!
# (25536, 153600) exists in coords!
# (70272, 127808) exists in coords!
# (28096, 70848) exists in coords!
# (24000, 153856) exists in coords!
# (52800, 138368) exists in coords!
# (26560, 71104) exists in coords!
# (24512, 81600) exists in coords!
# (51264, 138624) exists in coords!
# (40384, 114880) exists in coords!
# (47808, 77504) exists in coords!
# (36800, 151296) exists in coords!
# (22976, 81856) exists in coords!
# (20928, 92352) exists in coords!
# (33984, 69568) exists in coords!
# (15552, 93376) exists in coords!
# (63104, 123456) exists in coords!
# (32448, 69824) exists in coords!
# (53312, 138112) exists in coords!
# (30400, 80320) exists in coords!
# (26816, 91072) exists in coords!
# (39872, 68288) exists in coords!
# (21440, 92096) exists in coords!
# (68992, 122176) exists in coords!
# (37824, 78784) exists in coords!
# (29632, 121280) exists in coords!
# (4800, 125632) exists in coords!
# (61568, 133696) exists in coords!
# (36288, 79040) exists in coords!
# (11456, 83392) exists in coords!
# (19904, 153856) exists in coords!
# (28864, 90560) exists in coords!
# (57536, 85440) exists in coords!
# (39104, 109248) exists in coords!
# (22464, 71104) exists in coords!
# (32704, 89792) exists in coords!
# (41152, 160256) exists in coords!
# (31680, 120768) exists in coords!
# (27328, 90816) exists in coords!
# (43712, 77504) exists in coords!
# (6848, 125120) exists in coords!
# (67456, 132416) exists in coords!
# (42176, 77760) exists in coords!
# (61056, 112960) exists in coords!
# (26560, 157440) exists in coords!
# (23744, 101568) exists in coords!
# (3264, 135872) exists in coords!
# (34752, 89280) exists in coords!
# (77184, 110016) exists in coords!
# (28352, 69824) exists in coords!
# (57472, 123712) exists in coords!
# (47040, 158976) exists in coords!
# (75648, 110272) exists in coords!
# (49600, 76224) exists in coords!
# (41408, 118720) exists in coords!
# (10688, 134336) exists in coords!
# (44224, 77248) exists in coords!
# (9152, 134592) exists in coords!
# (22208, 111808) exists in coords!
# (87040, 10432) exists in coords!
# (63360, 122432) exists in coords!
# (21184, 65472) exists in coords!
# (43456, 118208) exists in coords!
# (18624, 122560) exists in coords!
# (17600, 76224) exists in coords!
# (65408, 121920) exists in coords!
# (14016, 86976) exists in coords!
# (15488, 17472) exists in coords!
# (27072, 64192) exists in coords!
# (45760, 153344) exists in coords!
# (61824, 132672) exists in coords!
# (51776, 131712) exists in coords!
# (19648, 75712) exists in coords!
# (20928, 157696) exists in coords!
# (29888, 94400) exists in coords!
# (23488, 74944) exists in coords!
# (18112, 75968) exists in coords!
# (34496, 62656) exists in coords!
# (16064, 86464) exists in coords!
# (7872, 128960) exists in coords!
# (28352, 156160) exists in coords!
# (32960, 62912) exists in coords!
# (14528, 86720) exists in coords!
# (30912, 73408) exists in coords!
# (25536, 74432) exists in coords!
# (26816, 156416) exists in coords!
# (52288, 131456) exists in coords!
# (29376, 73664) exists in coords!
# (24000, 74688) exists in coords!
# (40384, 61376) exists in coords!
# (50624, 80064) exists in coords!
# (32192, 103872) exists in coords!
# (35008, 62400) exists in coords!
# (45248, 81088) exists in coords!
# (24768, 115392) exists in coords!
# (38848, 61632) exists in coords!
# (36800, 72128) exists in coords!
# (28864, 155904) exists in coords!
# (18368, 95936) exists in coords!
# (31424, 73152) exists in coords!
# (60544, 127040) exists in coords!
# (35264, 72384) exists in coords!
# (52672, 79552) exists in coords!
# (27840, 83904) exists in coords!
# (25792, 94400) exists in coords!
# (51136, 79808) exists in coords!
# (49088, 90304) exists in coords!
# (30656, 114112) exists in coords!
# (24256, 94656) exists in coords!
# (71808, 124736) exists in coords!
# (3776, 128960) exists in coords!
# (37312, 71872) exists in coords!
# (18880, 95680) exists in coords!
# (47552, 90560) exists in coords!
# (66432, 125760) exists in coords!
# (29120, 114368) exists in coords!
# (62016, 139392) exists in coords!
# (2240, 129216) exists in coords!
# (33728, 82624) exists in coords!
# (52608, 117824) exists in coords!
# (76160, 103360) exists in coords!
# (41920, 111808) exists in coords!
# (57024, 78528) exists in coords!
# (54976, 89024) exists in coords!
# (73856, 124224) exists in coords!
# (30144, 93376) exists in coords!
# (53440, 89280) exists in coords!
# (72320, 124480) exists in coords!
# (41152, 81088) exists in coords!
# (4288, 128704) exists in coords!
# (70272, 134976) exists in coords!
# (8128, 127936) exists in coords!
# (64896, 136000) exists in coords!
# (43968, 111296) exists in coords!
# (58496, 116544) exists in coords!
# (68736, 135232) exists in coords!
# (26560, 78272) exists in coords!
# (42432, 111552) exists in coords!
# (54912, 127296) exists in coords!
# (22976, 89024) exists in coords!
# (47040, 79808) exists in coords!
# (10176, 127424) exists in coords!
# (35264, 158720) exists in coords!
# (70784, 134720) exists in coords!
# (9152, 81088) exists in coords!
# (29888, 159744) exists in coords!
# (86016, 13760) exists in coords!
# (25024, 114368) exists in coords!
# (32448, 76992) exists in coords!
# (80512, 112320) exists in coords!
# (46272, 120768) exists in coords!
# (44736, 121024) exists in coords!
# (21440, 99264) exists in coords!
# (15040, 79808) exists in coords!
# (9664, 80832) exists in coords!
# (38336, 75712) exists in coords!
# (11456, 90560) exists in coords!
# (59584, 82112) exists in coords!
# (24512, 67776) exists in coords!
# (53632, 121664) exists in coords!
# (22464, 78272) exists in coords!
# (43200, 156928) exists in coords!
# (49216, 135296) exists in coords!
# (27328, 97984) exists in coords!
# (20928, 78528) exists in coords!
# (15552, 79552) exists in coords!
# (31936, 66240) exists in coords!
# (13504, 90048) exists in coords!
# (5312, 132544) exists in coords!
# (17344, 89280) exists in coords!
# (25792, 159744) exists in coords!
# (16320, 120256) exists in coords!
# (11968, 90304) exists in coords!
# (30400, 66496) exists in coords!
# (59520, 120384) exists in coords!
# (28352, 76992) exists in coords!
# (20160, 119488) exists in coords!
# (55104, 134016) exists in coords!
# (12736, 131008) exists in coords!
# (26816, 77248) exists in coords!
# (37824, 64960) exists in coords!
# (19392, 88768) exists in coords!
# (48064, 83648) exists in coords!
# (11200, 131264) exists in coords!
# (23232, 88000) exists in coords!
# (61568, 119872) exists in coords!
# (22208, 118976) exists in coords!
# (87040, 17600) exists in coords!
# (63360, 129600) exists in coords!
# (26048, 118208) exists in coords!
# (28864, 76736) exists in coords!
# (20672, 119232) exists in coords!
# (37056, 105920) exists in coords!
# (47296, 124608) exists in coords!
# (50112, 83136) exists in coords!
# (25280, 87488) exists in coords!
# (53952, 82368) exists in coords!
# (48576, 83392) exists in coords!
# (67456, 118592) exists in coords!
# (65408, 129088) exists in coords!
# (28096, 117696) exists in coords!
# (21696, 98240) exists in coords!
# (50368, 93120) exists in coords!
# (69248, 128320) exists in coords!
# (1216, 132544) exists in coords!
# (49344, 124096) exists in coords!
# (63872, 129344) exists in coords!
# (53824, 128384) exists in coords!
# (22976, 154368) exists in coords!
# (37568, 105664) exists in coords!
# (47808, 124352) exists in coords!
# (50048, 121408) exists in coords!
# (39360, 115392) exists in coords!
# (18112, 83136) exists in coords!
# (71296, 127808) exists in coords!
# (14528, 93888) exists in coords!
# (69760, 128064) exists in coords!
# (52288, 138624) exists in coords!
# (16576, 119232) exists in coords!
# (24000, 81856) exists in coords!
# (50752, 138880) exists in coords!
# (39872, 115136) exists in coords!
# (36288, 151552) exists in coords!
# (38848, 68800) exists in coords!
# (20416, 92608) exists in coords!
# (13440, 14144) exists in coords!
# (35264, 79552) exists in coords!
# (29888, 80576) exists in coords!
# (11904, 14400) exists in coords!
# (40896, 68288) exists in coords!
# (51136, 86976) exists in coords!
# (26304, 91328) exists in coords!
# (5824, 125632) exists in coords!
# (37312, 79040) exists in coords!
# (29120, 121536) exists in coords!
# (12480, 83392) exists in coords!
# (60032, 113472) exists in coords!
# (35776, 79296) exists in coords!
# (54656, 114496) exists in coords!
# (33728, 89792) exists in coords!
# (50240, 128128) exists in coords!
# (57024, 85696) exists in coords!
# (21952, 71360) exists in coords!
# (50624, 66240) exists in coords!
# (32192, 90048) exists in coords!
# (19904, 81856) exists in coords!
# (40640, 160512) exists in coords!
# (43200, 77760) exists in coords!
# (72320, 131648) exists in coords!
# (4288, 135872) exists in coords!
# (18368, 82112) exists in coords!
# (8128, 135104) exists in coords!
# (41664, 78016) exists in coords!
# (60544, 113216) exists in coords!
# (58496, 123712) exists in coords!
# (2752, 136128) exists in coords!
# (14784, 92864) exists in coords!
# (34240, 89536) exists in coords!
# (76672, 110272) exists in coords!
# (13760, 123840) exists in coords!
# (42432, 118720) exists in coords!
# (56960, 123968) exists in coords!
# (25792, 80576) exists in coords!
# (46528, 159232) exists in coords!
# (17600, 123072) exists in coords!
# (52544, 137600) exists in coords!
# (36032, 99264) exists in coords!
# (75136, 110528) exists in coords!
# (49088, 76480) exists in coords!
# (47040, 86976) exists in coords!
# (28608, 110784) exists in coords!
# (10176, 134592) exists in coords!
# (16832, 92352) exists in coords!
# (64384, 122432) exists in coords!
# (8640, 134848) exists in coords!
# (27072, 111040) exists in coords!
# (25024, 121536) exists in coords!
# (59008, 123456) exists in coords!
# (38080, 98752) exists in coords!
# (19648, 122560) exists in coords!
# (62848, 122688) exists in coords!
# (13248, 103104) exists in coords!
# (60800, 133184) exists in coords!
# (20672, 65728) exists in coords!
# (23488, 121792) exists in coords!
# (36544, 99008) exists in coords!
# (52928, 85696) exists in coords!
# (17088, 76480) exists in coords!
# (41152, 67264) exists in coords!
# (51392, 85952) exists in coords!
# (70272, 121152) exists in coords!
# (30912, 120256) exists in coords!
# (25536, 121280) exists in coords!
# (21952, 157696) exists in coords!
# (66688, 131904) exists in coords!
# (26560, 64448) exists in coords!
# (29376, 120512) exists in coords!
# (45248, 153600) exists in coords!
# (61312, 132928) exists in coords!
# (51264, 131968) exists in coords!
# (40384, 108224) exists in coords!
# (47808, 70848) exists in coords!
# (22976, 75200) exists in coords!
# (33984, 62912) exists in coords!
# (15552, 86720) exists in coords!
# (27840, 156416) exists in coords!
# (32448, 63168) exists in coords!
# (53312, 131456) exists in coords!
# (30400, 73664) exists in coords!
# (26304, 156672) exists in coords!
# (26816, 84416) exists in coords!
# (39872, 61632) exists in coords!
# (23232, 95168) exists in coords!
# (38336, 61888) exists in coords!
# (36288, 72384) exists in coords!
# (17856, 96192) exists in coords!
# (28864, 83904) exists in coords!
# (32704, 83136) exists in coords!
# (51584, 118336) exists in coords!
# (27328, 84160) exists in coords!
# (25280, 94656) exists in coords!
# (48576, 90560) exists in coords!
# (67456, 125760) exists in coords!
# (23744, 94912) exists in coords!
# (3264, 129216) exists in coords!
# (34752, 82624) exists in coords!
# (9920, 86976) exists in coords!
# (38592, 81856) exists in coords!
# (57472, 117056) exists in coords!
# (1728, 129472) exists in coords!
# (47040, 152320) exists in coords!
# (33216, 82880) exists in coords!
# (52096, 118080) exists in coords!
# (31168, 93376) exists in coords!
# (41408, 112064) exists in coords!
# (10688, 127680) exists in coords!
# (54464, 89280) exists in coords!
# (73344, 124480) exists in coords!
# (48064, 69824) exists in coords!
# (29632, 93632) exists in coords!
# (9152, 127936) exists in coords!
# (40640, 81344) exists in coords!
# (69760, 135232) exists in coords!
# (44480, 80576) exists in coords!
# (84992, 14272) exists in coords!
# (43456, 111552) exists in coords!
# (57984, 116800) exists in coords!
# (81536, 102336) exists in coords!
# (33472, 102848) exists in coords!
# (46528, 80064) exists in coords!
# (85504, 14016) exists in coords!
# (61824, 126016) exists in coords!
# (24512, 114624) exists in coords!
# (23488, 68288) exists in coords!
# (45760, 121024) exists in coords!
# (31936, 113088) exists in coords!
# (14528, 80064) exists in coords!
# (67712, 124736) exists in coords!
# (25536, 67776) exists in coords!
# (29376, 67008) exists in coords!
# (50240, 135296) exists in coords!
# (10944, 90816) exists in coords!
# (64128, 135488) exists in coords!
# (24000, 68032) exists in coords!
# (21952, 78528) exists in coords!
# (23232, 160512) exists in coords!
# (42688, 157184) exists in coords!
# (32192, 97216) exists in coords!
# (45248, 74432) exists in coords!
# (20416, 78784) exists in coords!
# (36800, 65472) exists in coords!
# (18368, 89280) exists in coords!
# (31424, 66496) exists in coords!
# (12992, 90304) exists in coords!
# (60544, 120384) exists in coords!
# (50112, 155648) exists in coords!
# (35264, 65728) exists in coords!
# (56128, 134016) exists in coords!
# (25280, 160000) exists in coords!
# (53952, 154880) exists in coords!
# (14784, 100032) exists in coords!
# (29888, 66752) exists in coords!
# (34240, 96704) exists in coords!
# (27840, 77248) exists in coords!
# (54592, 134272) exists in coords!
# (26304, 77504) exists in coords!
# (24256, 88000) exists in coords!
# (37312, 65216) exists in coords!
# (18880, 89024) exists in coords!
# (47552, 83904) exists in coords!
# (27072, 118208) exists in coords!
# (31168, 158720) exists in coords!
# (33728, 75968) exists in coords!
# (15296, 99776) exists in coords!
# (62848, 129856) exists in coords!
# (36544, 106176) exists in coords!
# (30144, 86720) exists in coords!
# (53440, 82624) exists in coords!
# (41152, 74432) exists in coords!
# (22720, 98240) exists in coords!
# (4288, 122048) exists in coords!
# (51392, 93120) exists in coords!
# (8128, 121280) exists in coords!
# (64896, 129344) exists in coords!
# (39616, 74688) exists in coords!
# (21184, 98496) exists in coords!
# (24000, 154368) exists in coords!
# (68736, 128576) exists in coords!
# (704, 132800) exists in coords!
# (25792, 66752) exists in coords!
# (40384, 115392) exists in coords!
# (36032, 85440) exists in coords!
# (54912, 120640) exists in coords!
# (10176, 120768) exists in coords!
# (38848, 115648) exists in coords!
# (51904, 92864) exists in coords!
# (70784, 128064) exists in coords!
# (6592, 131520) exists in coords!
# (32448, 70336) exists in coords!
# (46272, 114112) exists in coords!
# (60800, 119360) exists in coords!
# (40896, 115136) exists in coords!
# (37312, 151552) exists in coords!
# (44736, 114368) exists in coords!
# (35776, 151808) exists in coords!
# (38336, 69056) exists in coords!
# (11456, 83904) exists in coords!
# (12928, 14400) exists in coords!
# (53632, 115008) exists in coords!
# (49216, 128640) exists in coords!
# (27328, 91328) exists in coords!
# (47680, 128896) exists in coords!
# (31936, 59584) exists in coords!
# (13504, 83392) exists in coords!
# (5312, 125888) exists in coords!
# (17344, 82624) exists in coords!
# (25792, 153088) exists in coords!
# (11968, 83648) exists in coords!
# (59520, 113728) exists in coords!
# (28352, 70336) exists in coords!
# (24256, 153344) exists in coords!
# (33216, 90048) exists in coords!
# (49728, 128384) exists in coords!
# (26816, 70592) exists in coords!
# (44224, 77760) exists in coords!
# (19392, 82112) exists in coords!
# (48064, 76992) exists in coords!
# (40128, 160768) exists in coords!
# (11200, 124608) exists in coords!
# (23232, 81344) exists in coords!
# (42688, 78016) exists in coords!
# (61568, 113216) exists in coords!
# (17856, 82368) exists in coords!
# (15808, 92864) exists in coords!
# (28864, 70080) exists in coords!
# (57984, 123968) exists in coords!
# (18624, 123072) exists in coords!
# (14272, 93120) exists in coords!
# (32704, 69312) exists in coords!
# (50112, 76480) exists in coords!
# (31680, 100288) exists in coords!
# (56448, 124224) exists in coords!
# (25280, 80832) exists in coords!
# (17088, 123328) exists in coords!
# (48576, 76736) exists in coords!
# (46528, 87232) exists in coords!
# (65408, 122432) exists in coords!
# (9664, 134848) exists in coords!
# (21696, 91584) exists in coords!
# (50368, 86464) exists in coords!
# (69248, 121664) exists in coords!
# (34752, 68800) exists in coords!
# (63872, 122688) exists in coords!
# (26560, 111296) exists in coords!
# (61824, 133184) exists in coords!
# (24512, 121792) exists in coords!
# (37568, 99008) exists in coords!
# (31168, 79552) exists in coords!
# (22976, 122048) exists in coords!
# (39360, 108736) exists in coords!
# (52416, 85952) exists in coords!
# (71296, 121152) exists in coords!
# (31936, 120256) exists in coords!
# (27584, 90304) exists in coords!
# (50880, 86208) exists in coords!
# (69760, 121408) exists in coords!
# (67712, 131904) exists in coords!
# (30400, 120512) exists in coords!
# (5568, 124864) exists in coords!
# (62336, 132928) exists in coords!
# (52288, 131968) exists in coords!
# (21440, 157952) exists in coords!
# (66176, 132160) exists in coords!
# (24000, 75200) exists in coords!
# (50752, 132224) exists in coords!
# (39872, 108480) exists in coords!
# (58304, 84672) exists in coords!
# (52352, 124224) exists in coords!
# (28864, 156416) exists in coords!
# (68224, 131648) exists in coords!
# (27328, 156672) exists in coords!
# (72064, 130880) exists in coords!
# (29888, 73920) exists in coords!
# (56640, 130944) exists in coords!
# (43712, 117696) exists in coords!
# (26304, 84672) exists in coords!
# (37312, 72384) exists in coords!
# (18880, 96192) exists in coords!
# (29120, 114880) exists in coords!
# (35776, 72640) exists in coords!
# (8896, 87488) exists in coords!
# (32192, 83392) exists in coords!
# (51072, 118592) exists in coords!
# (14208, 17216) exists in coords!
# (24768, 94912) exists in coords!
# (18368, 75456) exists in coords!
# (8128, 128448) exists in coords!
# (41664, 71360) exists in coords!
# (39616, 81856) exists in coords!
# (58496, 117056) exists in coords!
# (2752, 129472) exists in coords!
# (14784, 86208) exists in coords!
# (34240, 82880) exists in coords!
# (76672, 103616) exists in coords!
# (16256, 16704) exists in coords!
# (27840, 63424) exists in coords!
# (56960, 117312) exists in coords!
# (25792, 73920) exists in coords!
# (46528, 152576) exists in coords!
# (17600, 116416) exists in coords!
# (52544, 130944) exists in coords!
# (30656, 93632) exists in coords!
# (10176, 127936) exists in coords!
# (24256, 74176) exists in coords!
# (47552, 70080) exists in coords!
# (16832, 85696) exists in coords!
# (45504, 80576) exists in coords!
# (8640, 128192) exists in coords!
# (40128, 81600) exists in coords!
# (59008, 116800) exists in coords!
# (82560, 102336) exists in coords!
# (62848, 116032) exists in coords!
# (84480, 14528) exists in coords!
# (60800, 126528) exists in coords!
# (23488, 115136) exists in coords!
# (81024, 102592) exists in coords!
# (55424, 127552) exists in coords!
# (52928, 79040) exists in coords!
# (34496, 102848) exists in coords!
# (51392, 79296) exists in coords!
# (32960, 103104) exists in coords!
# (30912, 113600) exists in coords!
# (86528, 14016) exists in coords!
# (19136, 95168) exists in coords!
# (66688, 125248) exists in coords!
# (29376, 113856) exists in coords!
# (46784, 121024) exists in coords!
# (61312, 126272) exists in coords!
# (35008, 102592) exists in coords!
# (45248, 121280) exists in coords!
# (38848, 101824) exists in coords!
# (41664, 157696) exists in coords!
# (15552, 80064) exists in coords!
# (49856, 89536) exists in coords!
# (31424, 113344) exists in coords!
# (11968, 90816) exists in coords!
# (65152, 135488) exists in coords!
# (49728, 135552) exists in coords!
# (76928, 102592) exists in coords!
# (53568, 134784) exists in coords!
# (21440, 78784) exists in coords!
# (55744, 88256) exists in coords!
# (74624, 123456) exists in coords!
# (36288, 65728) exists in coords!
# (17856, 89536) exists in coords!
# (54976, 154880) exists in coords!
# (71040, 134208) exists in coords!
# (28864, 77248) exists in coords!
# (30144, 159232) exists in coords!
# (20672, 119744) exists in coords!
# (55616, 134272) exists in coords!
# ...
# (47552, 84160) exists in coords!
# (27072, 118464) exists in coords!
# (31168, 158976) exists in coords!
# (33728, 76224) exists in coords!
# (15296, 100032) exists in coords!
# (62848, 130112) exists in coords!
# (36544, 106432) exists in coords!
# (30144, 86976) exists in coords!
# (53440, 82880) exists in coords!
# (41152, 74688) exists in coords!
# (22720, 98496) exists in coords!
# (4288, 122304) exists in coords!
# (70272, 128576) exists in coords!
# (32960, 117184) exists in coords!
# (51392, 93376) exists in coords!
# (8128, 121536) exists in coords!
# (64896, 129600) exists in coords!
# (39616, 74944) exists in coords!
# (24000, 154624) exists in coords!
# (68736, 128832) exists in coords!
# (704, 133056) exists in coords!
# (40384, 115648) exists in coords!
# (54912, 120896) exists in coords!
# (10176, 121024) exists in coords!
# (38848, 115904) exists in coords!
# (51904, 93120) exists in coords!
# (70784, 128320) exists in coords!
# (6592, 131776) exists in coords!
# (32448, 70592) exists in coords!
# (57152, 138112) exists in coords!
# (46272, 114368) exists in coords!
# (60800, 119616) exists in coords!
# (40896, 115392) exists in coords!
# (34496, 95936) exists in coords!
# (37312, 151808) exists in coords!
# (44736, 114624) exists in coords!
# (35776, 152064) exists in coords!
# (38336, 69312) exists in coords!
# (11456, 84160) exists in coords!
# (12928, 14656) exists in coords!
# (53632, 115264) exists in coords!
# (49216, 128896) exists in coords!
# (27328, 91584) exists in coords!
# (47680, 129152) exists in coords!
# (31936, 59840) exists in coords!
# (13504, 83648) exists in coords!
# (42176, 78528) exists in coords!
# (5312, 126144) exists in coords!
# (17344, 82880) exists in coords!
# (25792, 153344) exists in coords!
# (11968, 83904) exists in coords!
# (59520, 113984) exists in coords!
# (28352, 70592) exists in coords!
# (24256, 153600) exists in coords!
# (33216, 90304) exists in coords!
# (75648, 111040) exists in coords!
# (51648, 66496) exists in coords!
# (26816, 70848) exists in coords!
# (44224, 78016) exists in coords!
# (19392, 82368) exists in coords!
# (48064, 77248) exists in coords!
# (40128, 161024) exists in coords!
# (11200, 124864) exists in coords!
# (23232, 81600) exists in coords!
# (42688, 78272) exists in coords!
# (61568, 113472) exists in coords!
# (15808, 93120) exists in coords!
# (87040, 11200) exists in coords!
# (63360, 123200) exists in coords!
# (28864, 70336) exists in coords!
# (57984, 124224) exists in coords!
# (32704, 69568) exists in coords!
# (50112, 76736) exists in coords!
# (31680, 100544) exists in coords!
# (56448, 124480) exists in coords!
# (25280, 81088) exists in coords!
# (35520, 99776) exists in coords!
# (17088, 123584) exists in coords!
# (48576, 76992) exists in coords!
# (46528, 87488) exists in coords!
# (65408, 122688) exists in coords!
# (9664, 135104) exists in coords!
# (28096, 111296) exists in coords!
# (21696, 91840) exists in coords!
# (50368, 86720) exists in coords!
# (69248, 121920) exists in coords!
# (34752, 69056) exists in coords!
# (63872, 122944) exists in coords!
# (26560, 111552) exists in coords!
# (61824, 133440) exists in coords!
# (37568, 99264) exists in coords!
# (31168, 79808) exists in coords!
# (22976, 122304) exists in coords!
# (39360, 108992) exists in coords!
# (52416, 86208) exists in coords!
# (71296, 121408) exists in coords!
# (31936, 120512) exists in coords!
# (27584, 90560) exists in coords!
# (69760, 121664) exists in coords!
# (67712, 132160) exists in coords!
# (30400, 120768) exists in coords!
# (26816, 157184) exists in coords!
# (62336, 133184) exists in coords!
# (52288, 132224) exists in coords!
# (21440, 158208) exists in coords!
# (66176, 132416) exists in coords!
# (24000, 75456) exists in coords!
# (50752, 132480) exists in coords!
# (39872, 108736) exists in coords!
# (58304, 84928) exists in coords!
# (52352, 124480) exists in coords!
# (38848, 62400) exists in coords!
# (28864, 156672) exists in coords!
# (68224, 131904) exists in coords!
# (35264, 73152) exists in coords!
# (27328, 156928) exists in coords!
# (29888, 74176) exists in coords!
# (56640, 131200) exists in coords!
# (43712, 117952) exists in coords!
# (26304, 84928) exists in coords!
# (37312, 72640) exists in coords!
# (18880, 96448) exists in coords!
# (29120, 115136) exists in coords!
# (35776, 72896) exists in coords!
# (33728, 83392) exists in coords!
# (8896, 87744) exists in coords!
# (32192, 83648) exists in coords!
# (51072, 118848) exists in coords!
# (19904, 75456) exists in coords!
# (14208, 17472) exists in coords!
# (30144, 94144) exists in coords!
# (24768, 95168) exists in coords!
# (4288, 129472) exists in coords!
# (18368, 75712) exists in coords!
# (8128, 128704) exists in coords!
# (41664, 71616) exists in coords!
# (39616, 82112) exists in coords!
# (58496, 117312) exists in coords!
# (2752, 129728) exists in coords!
# (14784, 86464) exists in coords!
# (34240, 83136) exists in coords!
# (76672, 103872) exists in coords!
# (27840, 63680) exists in coords!
# (56960, 117568) exists in coords!
# (25792, 74176) exists in coords!
# (17600, 116672) exists in coords!
# (52544, 131200) exists in coords!
# (30656, 93888) exists in coords!
# (10176, 128192) exists in coords!
# (24256, 74432) exists in coords!
# (70784, 135488) exists in coords!
# (16832, 85952) exists in coords!
# (45504, 80832) exists in coords!
# (8640, 128448) exists in coords!
# (25024, 115136) exists in coords!
# (40128, 81856) exists in coords!
# (59008, 117056) exists in coords!
# (82560, 102592) exists in coords!
# (62848, 116288) exists in coords!
# (84480, 14784) exists in coords!
# (60800, 126784) exists in coords!
# (23488, 115392) exists in coords!
# (55424, 127808) exists in coords!
# (52928, 79296) exists in coords!
# (34496, 103104) exists in coords!
# (51392, 79552) exists in coords!
# (32960, 103360) exists in coords!
# (30912, 113856) exists in coords!
# (9664, 81600) exists in coords!
# (86528, 14272) exists in coords!
# (19136, 95424) exists in coords!
# (90368, 13504) exists in coords!
# (66688, 125504) exists in coords!
# (29376, 114112) exists in coords!
# (46784, 121280) exists in coords!
# (61312, 126528) exists in coords!
# (51264, 125568) exists in coords!
# (35008, 102848) exists in coords!
# (45248, 121536) exists in coords!
# (41664, 157952) exists in coords!
# (15552, 80320) exists in coords!
# (49856, 89792) exists in coords!
# (31424, 113600) exists in coords!
# (30400, 67264) exists in coords!
# (11968, 91072) exists in coords!
# (65152, 135744) exists in coords!
# (49728, 135808) exists in coords!
# (26816, 78016) exists in coords!
# (53568, 135040) exists in coords!
# (21440, 79040) exists in coords!
# (55744, 88512) exists in coords!
# (74624, 123712) exists in coords!
# (23232, 88768) exists in coords!
# (36288, 65984) exists in coords!
# (17856, 89792) exists in coords!
# (54976, 155136) exists in coords!
# (71040, 134464) exists in coords!
# (28864, 77504) exists in coords!
# (30144, 159488) exists in coords!
# (10432, 101312) exists in coords!
# (20672, 120000) exists in coords!
# (55616, 134528) exists in coords!
# (32704, 76736) exists in coords!
# (14272, 100544) exists in coords!
# (53440, 155392) exists in coords!
# (27328, 77760) exists in coords!
# (25280, 88256) exists in coords!
# (48576, 84160) exists in coords!
# (23744, 88512) exists in coords!
# (21696, 99008) exists in coords!
# (3264, 122816) exists in coords!
# (34752, 76224) exists in coords!
# (26560, 118720) exists in coords!
# (9920, 80576) exists in coords!
# (38592, 75456) exists in coords!
# (20160, 99264) exists in coords!
# (37568, 106432) exists in coords!
# (33216, 76480) exists in coords!
# (31168, 86976) exists in coords!
# (59840, 81856) exists in coords!
# (54464, 82880) exists in coords!
# (33984, 117184) exists in coords!
# (29632, 87232) exists in coords!
# (27584, 97728) exists in coords!
# (9152, 121536) exists in coords!
# (40640, 74944) exists in coords!
# (22208, 98752) exists in coords!
# (69760, 128832) exists in coords!
# (32448, 117440) exists in coords!
# (15808, 79296) exists in coords!
# (44480, 74176) exists in coords!
# (5568, 132288) exists in coords!
# (55936, 120896) exists in coords!
# (16576, 120000) exists in coords!
# (12224, 90048) exists in coords!
# (31680, 86720) exists in coords!
# (60352, 81600) exists in coords!
# (39872, 115904) exists in coords!
# (54400, 121152) exists in coords!
# (33472, 96448) exists in coords!
# (15040, 120256) exists in coords!
# (75648, 127552) exists in coords!
# (38336, 116160) exists in coords!
# (7616, 131776) exists in coords!
# (50368, 72896) exists in coords!
# (11456, 131008) exists in coords!
# (61824, 119616) exists in coords!
# (22464, 118720) exists in coords!
# (11904, 15168) exists in coords!
# (56640, 138368) exists in coords!
# (45760, 114624) exists in coords!
# (58240, 130368) exists in coords!
# (20928, 118976) exists in coords!
# (48832, 83136) exists in coords!
# (28352, 117440) exists in coords!
# (17792, 13888) exists in coords!
# (50240, 128896) exists in coords!
# (10944, 84416) exists in coords!
# (12416, 14912) exists in coords!
# (49600, 123840) exists in coords!
# (64128, 129088) exists in coords!
# (21952, 72128) exists in coords!
# (23232, 154112) exists in coords!
# (48704, 129152) exists in coords!
# (37824, 105408) exists in coords!
# (48064, 124096) exists in coords!
# (18368, 82880) exists in coords!
# (31424, 60096) exists in coords!
# (12992, 83904) exists in coords!
# (41664, 78784) exists in coords!
# (25280, 153600) exists in coords!
# (14784, 93632) exists in coords!
# (34240, 90304) exists in coords!
# (27840, 70848) exists in coords!
# (50112, 123584) exists in coords!
# (52544, 138368) exists in coords!
# (75136, 111296) exists in coords!
# (50368, 159232) exists in coords!
# (26304, 71104) exists in coords!
# (24256, 81600) exists in coords!
# (51008, 138624) exists in coords!
# (18880, 82624) exists in coords!
# (47552, 77504) exists in coords!
# (29120, 101312) exists in coords!
# (16832, 93120) exists in coords!
# (27072, 111808) exists in coords!
# (8640, 135616) exists in coords!
# (59008, 124224) exists in coords!
# (33728, 69568) exists in coords!
# (15296, 93376) exists in coords!
# (62848, 123456) exists in coords!
# (36544, 99776) exists in coords!
# (53056, 138112) exists in coords!
# (30144, 80320) exists in coords!
# (24768, 81344) exists in coords!
# (41152, 68032) exists in coords!
# (22720, 91840) exists in coords!
# (51392, 86720) exists in coords!
# (64896, 122944) exists in coords!
# (39616, 68288) exists in coords!
# (21184, 92096) exists in coords!
# (68736, 122176) exists in coords!
# (61312, 133696) exists in coords!
# (36032, 79040) exists in coords!
# (28608, 90560) exists in coords!
# (38848, 109248) exists in coords!
# (51904, 86464) exists in coords!
# (70784, 121664) exists in coords!
# (31424, 120768) exists in coords!
# (25024, 101312) exists in coords!
# (6592, 125120) exists in coords!
# (38080, 78528) exists in coords!
# (67200, 132416) exists in coords!
# (29888, 121024) exists in coords!
# (41920, 77760) exists in coords!
# (60800, 112960) exists in coords!
# (26304, 157440) exists in coords!
# (59328, 84928) exists in coords!
# (3008, 135872) exists in coords!
# (65664, 132672) exists in coords!
# (34496, 89280) exists in coords!
# (76928, 110016) exists in coords!
# (57792, 85184) exists in coords!
# (75392, 110272) exists in coords!
# (38336, 62656) exists in coords!
# (8896, 134592) exists in coords!
# (59264, 123200) exists in coords!
# (19904, 122304) exists in coords!
# (77440, 109760) exists in coords!
# (27328, 84928) exists in coords!
# (20928, 65472) exists in coords!
# (43200, 118208) exists in coords!
# (13504, 76992) exists in coords!
# (17344, 76224) exists in coords!
# (1728, 130240) exists in coords!
# (25792, 121024) exists in coords!
# (33216, 83648) exists in coords!
# (52096, 118848) exists in coords!
# (15232, 17472) exists in coords!
# (26816, 64192) exists in coords!
# (45504, 153344) exists in coords!
# (21440, 65216) exists in coords!
# (50560, 119104) exists in coords!
# (19392, 75712) exists in coords!
# (48064, 70592) exists in coords!
# (29632, 94400) exists in coords!
# (23232, 74944) exists in coords!
# (17856, 75968) exists in coords!
# (15808, 86464) exists in coords!
# (44480, 81344) exists in coords!
# (28864, 63680) exists in coords!
# (10432, 87488) exists in coords!
# (39104, 82368) exists in coords!
# (57984, 117568) exists in coords!
# (81536, 103104) exists in coords!
# (18624, 116672) exists in coords!
# (14272, 86720) exists in coords!
# (32704, 62912) exists in coords!
# (31680, 93888) exists in coords!
# (56448, 117824) exists in coords!
# (25280, 74432) exists in coords!
# (46016, 153088) exists in coords!
# (35520, 93120) exists in coords!
# (48576, 70336) exists in coords!
# (46528, 80832) exists in coords!
# (9664, 128448) exists in coords!
# (50368, 80064) exists in coords!
# (83584, 102592) exists in coords!
# (34752, 62400) exists in coords!
# (16320, 86208) exists in coords!
# (44992, 81088) exists in coords!
# (24512, 115392) exists in coords!
# (38592, 61632) exists in coords!
# (31168, 73152) exists in coords!
# (83968, 15040) exists in coords!
# (60288, 127040) exists in coords!
# (22976, 115648) exists in coords!
# (52416, 79552) exists in coords!
# (27584, 83904) exists in coords!
# (50880, 79808) exists in coords!
# (48832, 90304) exists in coords!
# (67712, 125504) exists in coords!
# (30400, 114112) exists in coords!
# (62336, 126528) exists in coords!
# (37056, 71872) exists in coords!
# (47296, 90560) exists in coords!
# (66176, 125760) exists in coords!
# (64128, 136256) exists in coords!
# (24000, 68800) exists in coords!
# (50752, 125824) exists in coords!
# (33472, 82624) exists in coords!
# (52352, 117824) exists in coords!
# (54720, 89024) exists in coords!
# (73600, 124224) exists in coords!
# (49344, 90048) exists in coords!
# (68224, 125248) exists in coords!
# (72064, 124480) exists in coords!
# (4032, 128704) exists in coords!
# (29888, 67520) exists in coords!
# (64640, 136000) exists in coords!
# (54592, 135040) exists in coords!
# (43712, 111296) exists in coords!
# (58240, 116544) exists in coords!
# (26304, 78272) exists in coords!
# (42176, 111552) exists in coords!
# (18880, 89792) exists in coords!
# (74112, 123968) exists in coords!
# (31168, 159488) exists in coords!
# (35776, 66240) exists in coords!
# (15296, 100544) exists in coords!
# (54464, 155392) exists in coords!
# (70528, 134720) exists in coords!
# (8896, 81088) exists in coords!
# (29632, 159744) exists in coords!
# (85760, 13760) exists in coords!
# (44224, 111040) exists in coords!
# (32192, 76992) exists in coords!
# (80256, 112320) exists in coords!
# (24768, 88512) exists in coords!
# (39616, 75456) exists in coords!
# (31680, 159232) exists in coords!
# (21184, 99264) exists in coords!
# (14784, 79808) exists in coords!
# (34240, 76480) exists in coords!
# (9408, 80832) exists in coords!
# (25792, 67520) exists in coords!
# (30656, 87232) exists in coords!
# (10176, 121536) exists in coords!
# (24256, 67776) exists in coords!
# (53376, 121664) exists in coords!
# (42944, 156928) exists in coords!
# (16832, 79296) exists in coords!
# (8640, 121792) exists in coords!
# (6592, 132288) exists in coords!
# (40128, 75200) exists in coords!
# (13248, 90048) exists in coords!
# (60800, 120128) exists in coords!
# (5056, 132544) exists in coords!
# (55424, 121152) exists in coords!
# (34496, 96448) exists in coords!
# (16064, 120256) exists in coords!
# (30144, 66496) exists in coords!
# (44736, 115136) exists in coords!
# (22720, 78016) exists in coords!
# (12480, 131008) exists in coords!
# (75136, 127808) exists in coords!
# (7104, 132032) exists in coords!
# (19136, 88768) exists in coords!
# (10944, 131264) exists in coords!
# (46784, 114624) exists in coords!
# (61312, 119872) exists in coords!
# (59264, 130368) exists in coords!
# (21952, 118976) exists in coords!
# (11392, 15424) exists in coords!
# (45248, 114880) exists in coords!
# (47680, 129664) exists in coords!
# (36800, 105920) exists in coords!
# (49856, 83136) exists in coords!
# (11968, 84416) exists in coords!
# (67200, 118592) exists in coords!
# (65152, 129088) exists in coords!
# (27840, 117696) exists in coords!
# (17280, 14144) exists in coords!
# (24256, 154112) exists in coords!
# (49728, 129152) exists in coords!
# (49088, 124096) exists in coords!
# (87296, 17344) exists in coords!
# (63616, 129344) exists in coords!
# (53568, 128384) exists in coords!
# (21440, 72384) exists in coords!
# (48192, 129408) exists in coords!
# (37312, 105664) exists in coords!
# (47552, 124352) exists in coords!
# (17856, 83136) exists in coords!
# (71040, 127808) exists in coords!
# (32704, 70080) exists in coords!
# (14272, 93888) exists in coords!
# (27328, 71104) exists in coords!

# %%
import openslide
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

def show_attention_on_region(_base_img, coords_, coords_attn_, 
                             patch_size=256, level=0, alpha=0.5,
                             region=None,
                             _mask_arr=None, mask_level=8):  # <<< 新增参数
    # * -------------- 读取原图片对应region部分（level0） --------------
    coords_set = set(map(tuple, coords_))

    heatmap = _base_img.copy()

    print("[INFO] Attn min:", attn_norm.min(), "max:", attn_norm.max(),"attn_norm shape",attn_norm.shape)
    
    for (x, y) in coords_set:
        if (x, y) in coords_attn_:
    # for i, (x, y) in enumerate(coords_): # x,x+256,y,y+256对应原图在level0的一个小方块
            x = int(x)
            y=int(y)
            # print(x,y) # 56960 113280 ; 56960 113536
            if not (left <= x < right and top <= y < bottom):
                continue  # skip patches outside region
            rel_x = int(x - left)
            rel_y = int(y - top)
            # print("pt1", (rel_x, rel_y), "pt2", (rel_x + 256, rel_y + 256))
            # pt1 (144, 400) pt2 (400, 656)
            # pt1 (13968, 7568) pt2 (14224, 7824)
            color = plt.cm.jet(coords_attn_[(x,y)])[:3]
            color = tuple(int(255 * c) for c in color)
            # 为每个 patch 用其 attention score 映射的颜色，画出对应的矩形区域，从而形成整个 attention heatmap 叠加图
            cv2.rectangle(
                img=heatmap,                          # 要画的图像（NumPy array，通常是 RGB）
                pt1=(rel_x, rel_y),                   # 左上角坐标
                pt2=(rel_x + 256, rel_y + 256), # 右下角坐标
                color=color,                          # 矩形颜色（B, G, R）格式
                thickness=-1                          # 填充整个矩形（如果是 2 表示边框宽度为 2）
            )
    print("aaa")
        # * -------------- 加载mask并绘制轮廓 --------------
        # if _mask_arr is not None:
            
        #     print(f"[INFO] Partial mask shape: {_mask_arr.shape}, unique labels: {np.unique(_mask_arr)}")
            
        #     # 提取 tumor 区域并绘制边界（仅 label==2）
        #     tumor_mask = (_mask_arr == 2).astype(np.uint8)
        #     count = np.sum(tumor_mask == 1) # tumor的mask只存在于图片左上角
        #     temp = np.argwhere(tumor_mask == 1)
        #     print(f"Found {len(temp)} coordinates with value 1:")
        #     for t in temp:
        #         rel_x, rel_y = t[0]*256, t[1]*256

        #         color =  (0, 0, 255) # 绿色
        #         # 为每个 patch 用其 attention score 映射的颜色，画出对应的矩形区域，从而形成整个 attention heatmap 叠加图
        #         cv2.rectangle(
        #             img=heatmap,                          # 要画的图像（NumPy array，通常是 RGB）
        #             pt1=(rel_x, rel_y),                   # 左上角坐标
        #             pt2=(rel_x + 256, rel_y + 256), # 右下角坐标
        #             color=color,                          # 矩形颜色（B, G, R）格式
        #             thickness=-1                          # 填充整个矩形（如果是 2 表示边框宽度为 2）
        #         )
            
    blended = cv2.addWeighted(heatmap, alpha, base_img, 1 - alpha, 0)

                
    # ------------------------------------------------

    # show image
    plt.figure(figsize=(10, 10))
    plt.imshow(blended)
    plt.axis("off")
    # plt.title("Attention Heatmap + Tumor Mask")
    plt.show()
    

# show_attention_on_region(
#     _base_img=base_img,
#     coords_=coords,
#     coords_attn_=coords_attn,
#     _mask_arr=mask_arr)

show_attention_on_region(
    _base_img=base_img,
    coords_=coords,
    coords_attn_=coords_attn_region_norm,
    _mask_arr=mask_arr)
# Out:
# [INFO] Attn min: 0.0 max: 0.9999863 attn_norm shape (36710,)
# aaa
