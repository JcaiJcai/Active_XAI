# %%
# 读取已生成的shap解释值
import torch
pt_path = "/u/jcai1/code/usefulxai/code/results/explanations/transmil_fold_0_shap1_2000/normal_001.pt"
data = torch.load(pt_path, map_location='cpu', weights_only=False)
print(data)
shap_score = list(data.values())[0]
print(len(shap_score), shap_score)
# Out:
# {'normal_001': array([3.2264277e-05, 3.2349268e-05, 3.7601934e-05, ..., 3.5378882e-05,
#        3.5686156e-05, 3.6646172e-05], dtype=float32)}
# 7974 [3.2264277e-05 3.2349268e-05 3.7601934e-05 ... 3.5378882e-05 3.5686156e-05
#  3.6646172e-05]

# %%
# 读取已生成的shap解释值
import torch
pt_path = "/u/jcai1/code/usefulxai/paper_results/explanations/transmil_fold_0_perturbation/normal_001.pt"
data = torch.load(pt_path, map_location='cpu', weights_only=False)
print(data)
shap_score = list(data.values())[0]
print(len(shap_score), shap_score)
# Out:
# {'normal_001': array([-1.196548  , -1.4281235 , -1.5672278 , ...,  0.04068851,
#         0.03555202,  0.03706074], dtype=float32)}
# 7974 [-1.196548   -1.4281235  -1.5672278  ...  0.04068851  0.03555202
#   0.03706074]
